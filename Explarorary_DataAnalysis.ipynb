# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Question 01)

# %% [markdown]
# a)

# %%
df = pd.read_csv('D:\\3rd year\\Sem 2\\Machine Learning\\automobile\\dataset.csv')
df.head(100)
# Out:
#     3  Unnamed: 1  alfa-romero  gas  std   two convertible  rwd  front   88.6  \
# 0   1         NaN  alfa-romero  gas  std   two   hatchback  rwd  front   94.5
# 1   2       164.0         audi  gas  std  four       sedan  fwd  front   99.8
# 2   2       164.0         audi  gas  std  four       sedan  4wd  front   99.4
# 3   2         NaN         audi  gas  std   two       sedan  fwd  front   99.8
# 4   1       158.0         audi  gas  std  four       sedan  fwd  front  105.8
# .. ..         ...          ...  ...  ...   ...         ...  ...    ...    ...
# 95  1       128.0       nissan  gas  std   two   hatchback  fwd  front   94.5
# 96  1       122.0       nissan  gas  std  four       sedan  fwd  front   94.5
# 97  1       103.0       nissan  gas  std  four       wagon  fwd  front   94.5
# 98  2       168.0       nissan  gas  std   two     hardtop  fwd  front   95.1
# 99  0       106.0       nissan  gas  std  four   hatchback  fwd  front   97.2
#
# ...

# %%
df.shape
# Out:
# (207, 26)

# %% [markdown]
# b)

# %%
#create labels for each column
column_name = ["Symbolling","Normalized-losses","Make","Fuel-type","Aspiration",
               "Num-of-doors","Body Style","Drive-wheels","Engine location","Wheel Base",
              "Length", "Width", "Height","Curb-weight", "Engine type","Num-of-Cylinders","Engine size",
              "Fuel-system","Bore","Stroke","Compression-ratio","HorsePower","Peak-rpm",
              "City-mpg","Highway-mpg","Price"]

# %%
df.columns = column_name

# %%
df
# Out:
#      Symbolling  Normalized-losses         Make Fuel-type Aspiration  \
# 0             1                NaN  alfa-romero       gas        std
# 1             2              164.0         audi       gas        std
# 2             2              164.0         audi       gas        std
# 3             2                NaN         audi       gas        std
# 4             1              158.0         audi       gas        std
# ..          ...                ...          ...       ...        ...
# 202          -1               95.0        volvo       gas        std
# 203          -1               95.0        volvo       gas      turbo
# 204          -1               95.0        volvo       gas        std
# 205          -1               95.0        volvo    diesel      turbo
# 206          -1               95.0        volvo       gas      turbo
#
#     Num-of-doors Body Style Drive-wheels Engine location  Wheel Base  ...  \
# ...

# %%
datatypes = df.dtypes

# %%
datatypes
# Out:
# Symbolling             int64
# Normalized-losses    float64
# Make                  object
# Fuel-type             object
# Aspiration            object
# Num-of-doors          object
# Body Style            object
# Drive-wheels          object
# Engine location       object
# Wheel Base           float64
# Length               float64
# Width                float64
# Height               float64
# Curb-weight            int64
# Engine type           object
# Num-of-Cylinders      object
# Engine size            int64
# Fuel-system           object
# Bore                 float64
# Stroke               float64
# Compression-ratio    float64
# HorsePower           float64
# Peak-rpm             float64
# City-mpg               int64
# Highway-mpg            int64
# Price                float64
# dtype: object

# %%
df.isna().head(10)
# Out:
#    Symbolling  Normalized-losses   Make  Fuel-type  Aspiration  Num-of-doors  \
# 0       False               True  False      False       False         False
# 1       False              False  False      False       False         False
# 2       False              False  False      False       False         False
# 3       False               True  False      False       False         False
# 4       False              False  False      False       False         False
# 5       False               True  False      False       False         False
# 6       False              False  False      False       False         False
# 7       False              False  False      False       False         False
# 8       False               True  False      False       False         False
# 9       False              False  False      False       False         False
#
#    Body Style  Drive-wheels  Engine location  Wheel Base  ...  Engine size  \
# ...

# %% [markdown]
# c)

# %%
missed_variables = pd.DataFrame({"Variables": df.columns , "No:of missed" : df.isna().sum()}).reset_index(drop=True)
missed_variables
# Out:
#             Variables  No:of missed
# 0          Symbolling             0
# 1   Normalized-losses            39
# 2                Make             0
# 3           Fuel-type             0
# 4          Aspiration             0
# 5        Num-of-doors             2
# 6          Body Style             0
# 7        Drive-wheels             0
# 8     Engine location             0
# 9          Wheel Base             0
# 10             Length             0
# 11              Width             0
# 12             Height             0
# 13        Curb-weight             0
# 14        Engine type             0
# 15   Num-of-Cylinders             0
# 16        Engine size             0
# 17        Fuel-system             0
# 18               Bore             4
# 19             Stroke             4
# 20  Compression-ratio             0
# 21         HorsePower             2
# 22           Peak-rpm             2
# 23           City-mpg             0
# 24        Highway-mpg             0
# ...

# %% [markdown]
# d)

# %%
duplicates = df.duplicated(keep = False)
duplicated_rows = df[duplicates]

num_duplicates = duplicates.sum()
df_unique = df.drop_duplicates()

print("Number of duplicate rows in the dataset : ",num_duplicates)
print("Number of unique rows in the datasheet : ", len(df_unique))
# Out:
# Number of duplicate rows in the dataset :  8
# Number of unique rows in the datasheet :  203

# %% [markdown]
# e)

# %%
print(duplicated_rows)
# Out:
#      Symbolling  Normalized-losses           Make Fuel-type Aspiration  \
# 6             1              101.0          honda       gas        std
# 31            1              101.0          honda       gas        std
# 48           -1               93.0  mercedes-benz    diesel      turbo
# 68           -1               93.0  mercedes-benz    diesel      turbo
# 100           0              106.0         nissan       gas        std
# 127           0              106.0         nissan       gas        std
# 142           1               87.0         toyota       gas        std
# 153           1               87.0         toyota       gas        std
#
#     Num-of-doors Body Style Drive-wheels Engine location  Wheel Base  ...  \
# 6            two  hatchback          fwd           front        93.7  ...
# 31           two  hatchback          fwd           front        93.7  ...
# 48          four      wagon          rwd           front       110.0  ...
# ...

# %% [markdown]
# f)

# %%
df_new = df_unique
df_new
# Out:
#      Symbolling  Normalized-losses         Make Fuel-type Aspiration  \
# 0             1                NaN  alfa-romero       gas        std
# 1             2              164.0         audi       gas        std
# 2             2              164.0         audi       gas        std
# 3             2                NaN         audi       gas        std
# 4             1              158.0         audi       gas        std
# ..          ...                ...          ...       ...        ...
# 202          -1               95.0        volvo       gas        std
# 203          -1               95.0        volvo       gas      turbo
# 204          -1               95.0        volvo       gas        std
# 205          -1               95.0        volvo    diesel      turbo
# 206          -1               95.0        volvo       gas      turbo
#
#     Num-of-doors Body Style Drive-wheels Engine location  Wheel Base  ...  \
# ...

# %% [markdown]
# g)

# %%
df_dropped = df_new.dropna()
df_dropped
# Out:
#      Symbolling  Normalized-losses   Make Fuel-type Aspiration Num-of-doors  \
# 1             2              164.0   audi       gas        std         four
# 2             2              164.0   audi       gas        std         four
# 4             1              158.0   audi       gas        std         four
# 6             1              101.0  honda       gas        std          two
# 7             1              158.0   audi       gas      turbo         four
# ..          ...                ...    ...       ...        ...          ...
# 202          -1               95.0  volvo       gas        std         four
# 203          -1               95.0  volvo       gas      turbo         four
# 204          -1               95.0  volvo       gas        std         four
# 205          -1               95.0  volvo    diesel      turbo         four
# 206          -1               95.0  volvo       gas      turbo         four
#
# ...

# %%
print("Number of remaining rows in the datasheet : ", len(df_dropped))
# Out:
# Number of remaining rows in the datasheet :  159
